# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
pd.read_csv(r"C:\Users\reals\Downloads\Diwali Sales Data.csv",encoding= 'unicode_escape')
# Reading the file
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df = pd.read_csv(r"C:\Users\reals\Downloads\Diwali Sales Data.csv",encoding= 'unicode_escape')
df.head() # Show first five rows of the csv file
df.columns # SHows Columns of the data set
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='object')

# %%
df.info() # Give the information of the dataset by showing their data type
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
df.shape # shows us the properties of how nany rows and columns are in the data
# Out:
# (11251, 15)

# %%
df.drop(['Status', 'unnamed1'], axis=1, inplace=True) # Deleting the unneccessary columns

# %%
df.info() # Checking if the coulumns are deleted or not
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.1+ MB

# %%
# checking if their are null values or not in data set
pd.isnull(df).sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
df.dropna(inplace=True)
#deleting null values

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders   Amount
# 0     Maharashtra   Western       Healthcare             Auto       1  23952.0
# 1  Andhra Pradesh  Southern             Govt             Auto       3  23934.0
# 2   Uttar Pradesh   Central       Automobile             Auto       3  23924.0
# 3       Karnataka  Southern     Construction             Auto       2  23912.0
# 4         Gujarat   Western  Food Processing             Auto       2  23877.0

# %%
# changing data type
df["Amount"]= df["Amount"].astype('int')

# %%
df['Amount'].dtype # dt is changed
# Out:
# dtype('int32')

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
#Rename Coulumn
df.rename(columns= {"Marital_Status":"Shaadi"})
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Shaadi  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28       0
# 1      1000732       Kartik  P00110942      F     26-35   35       1
# 2      1001990        Bindu  P00118542      F     26-35   35       1
# 3      1001425       Sudevi  P00237842      M      0-17   16       0
# 4      1000588         Joni  P00057942      M     26-35   28       1
# ...        ...          ...        ...    ...       ...  ...     ...
# 11246  1000695      Manning  P00296942      M     18-25   19       1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33       0
# 11248  1001209        Oshin  P00201342      F     36-45   40       0
# 11249  1004023       Noonan  P00059442      M     36-45   37       0
# 11250  1002744      Brumley  P00281742      F     18-25   19       0
#
#                 State      Zone       Occupation Product_Category  Orders  \
# ...

# %%
df[['Age','Orders','Amount']].describe()
# Gives the mathematical Calculations
# Out:
#                 Age        Orders        Amount
# count  11239.000000  11239.000000  11239.000000
# mean      35.410357      2.489634   9453.610553
# std       12.753866      1.114967   5222.355168
# min       12.000000      1.000000    188.000000
# 25%       27.000000      2.000000   5443.000000
# 50%       33.000000      2.000000   8109.000000
# 75%       43.000000      3.000000  12675.000000
# max       92.000000      4.000000  23952.000000

# %% [markdown]
# # Exploratory data analysis (EDA)

# %% [markdown]
# ### Gender

# %%
# Cretaing a bar plot using seaborn
ax = sns.countplot(x = 'Gender', data = df)

# %%
ax = sns.countplot(x = 'Gender', data = df)
# ADding data points into bar plot
for bars in ax.containers:
    ax.bar_label(bars)

# %%
df.groupby(['Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)
# Out:
#   Gender    Amount
# 0      F  74335853
# 1      M  31913276

# %%
sales = df.groupby(['Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)

sns.barplot(x= 'Gender', y='Amount', data=sales)
# Out:
# <Axes: xlabel='Gender', ylabel='Amount'>

# %% [markdown]
# ## Age

# %%
ax = sns.countplot(data=df, x= 'Age Group', hue ='Gender')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
# Total Amount vs Age group
sales_age = df.groupby(['Age Group'],as_index = False ).sum().sort_values(by='Amount',ascending= False)
sns.barplot(x = 'Age Group', y = 'Amount', data= sales_age)
# Out:
# <Axes: xlabel='Age Group', ylabel='Amount'>

# %% [markdown]
# From Above Graphs we can see that the most of the buyers are of age froup between 26-36 years female

# %% [markdown]
# ## State

# %%
# Total Numbers of oorders from top 10 states 
sales_state = df.groupby(['State'],as_index = False )['Orders'].sum().sort_values(by='Orders',ascending= False).head(10)
sns.set(rc={'figure.figsize':(16,5)})
sns.barplot(x = 'State', y = 'Orders', data= sales_state)
# Out:
# <Axes: xlabel='State', ylabel='Orders'>

# %%
# Total Amount / sales from top ten states
sales_state = df.groupby(['State'],as_index = False )['Amount'].sum().sort_values(by='Amount',ascending= False).head(10)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(x = 'State', y = 'Amount', data= sales_state)
# Out:
# <Axes: xlabel='State', ylabel='Amount'>

# %% [markdown]
# from above graph we can see that unexpected most of the orders are from uter pardesh , maharashtra and Karnataka respectively but total sales / ampount is from Up, katnataka and maharashtra .

# %% [markdown]
# ## Marital status

# %%
ax = sns.countplot(data = df , x = "Marital_Status")
print(df.groupby(["Marital_Status"],as_index=False))
sns.set(rc={'figure.figsize':(6,6)})
for  bars in ax.containers:
    ax.bar_label(bars)
# Out:
# <bound method Series.count of 0        0
# 1        1
# 2        1
# 3        0
# 4        1
#         ..
# 11246    1
# 11247    0
# 11248    0
# 11249    0
# 11250    0
# Name: Marital_Status, Length: 11239, dtype: int64>

# %%
sales_ms = df.groupby(['Marital_Status',"Gender"],as_index = False )['Amount'].sum().sort_values(by='Amount',ascending= False).head(10)
sns.set(rc={'figure.figsize':(5,5)})
sns.barplot(x = 'Marital_Status',hue="Gender", y = 'Amount', data= sales_ms)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='Amount'>

# %% [markdown]
# From above graph we can see that most of the buyers are married (women) and they hava high purchasing power

# %% [markdown]
# ## Ocupation

# %%
ax = sns.countplot(data = df , x = "Occupation")
sns.set(rc={'figure.figsize':(30,5)})
for  bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_occupation = df.groupby(['Occupation'],as_index = False )['Amount'].sum().sort_values(by='Amount',ascending= False).head(10)
sns.set(rc={'figure.figsize':(30,5)})
sns.barplot(data = sales_occupation, x ="Occupation", y= "Amount")
# Out:
# <Axes: xlabel='Occupation', ylabel='Amount'>

# %% [markdown]
# from above graph most of the buyers are from IT SectOr , Healthcare , And Aviation.

# %% [markdown]
# ## Product Category

# %%
ax = sns.countplot(data = df , x = "Product_Category")
sns.set(rc={'figure.figsize':(30,5)})

for  bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_PC = df.groupby(['Product_Category'],as_index = False )['Amount'].sum().sort_values(by='Amount',ascending= False).head()
sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data = sales_PC, x ="Product_Category", y= "Amount")
# Out:
# <Axes: xlabel='Product_Category', ylabel='Amount'>

# %% [markdown]
# From above graph we can see most of the product sales are from Foods, Clothing and Electronics...

# %%
sales_PID = df.groupby(['Product_ID'],as_index = False )['Orders'].sum().sort_values(by='Orders',ascending= False).head()
sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data = sales_PID, x ="Product_ID", y= "Orders")
# Out:
# <Axes: xlabel='Product_ID', ylabel='Orders'>

# %%
 # Top 10 sold Products (Same thing above)

fig1, ax = plt.subplots(figsize=(12,7))
df.groupby('Product_ID')['Orders'].sum().nlargest(10).sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Product_ID'>

# %% [markdown]
# # Conclusion

# %% [markdown]
# Mrried women Age group 26-36 years From UP, Maharashtra, Karnataka working in IT, Healthcare and Aviation are more liked by products from Food , Clothing and Electronics Category
